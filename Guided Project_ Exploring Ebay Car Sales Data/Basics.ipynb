# %% [markdown]
# # E-Bay car sales
#
# In this project, we'll work with a dataset of used cars from eBay Kleinanzeigen, a classifieds section of the German eBay website.
#
# The dataset was originally scraped and uploaded to Kaggle. The aim of this project is to clean the data and analyze the included used car listings.

# %%
import numpy as np
import pandas as pd

# %%
autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# # Step 1, Summary
#
# The list has 50K rows and 20 columns. It is a mixture of strings and integers. 5 of the 20 columns are missing values.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.rename({"yearOfRegistration": "registration_year",
             "monthOfRegistration": "registration_month",
             "notRepairedDamage": "unrepaired_damage",
             "dateCreated":"ad_created",
             "dateCrawled":"date_crawled",
             "offerType":"offer_type",
             "vehicleType":"vehicle_type",
             "fuelType":"fuel_type",
             "nrOfPictures":"nr_of_pictures",
             "postalCode":"postal_code",
             "lastSeen":"last_seen",
             "powerPS":"power_ps"}, axis=1, inplace=True)

# %% [markdown]
# # Step 2
#
# Columns renamed so they are all snakecase format

# %%
print(autos.columns)
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# # Step 3
#
#  Basic data exploration to determine what other cleaning tasks need to be done.

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-25 19:57:10  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %% [markdown]
# # Column analysis
#
# - date_crawled; has 3 entries and can be dropped.
# - seller and offer type; contain 99,99% same values, can be dropped.
# - Price; is numbers in string fformat, needs to be cleaned.
# - Vehicle type; has missing entires
# - registration year; contains years below 1900 and above 2020.
# - Gear box; has missing entries.

# %%
autos['registration_year'].value_counts()
reg_unique = autos['registration_year'].unique()
years_sorted = autos['registration_year'].sort_values()
print(reg_unique)
print(years_sorted)
# Out:
# [2004 1997 2009 2007 2003 2006 1995 1998 2000 2017 2010 1999 1982 1990
#  2015 2014 1996 1992 2005 2002 2012 2011 2008 1985 2016 1994 1986 2001
#  2018 2013 1972 1993 1988 1989 1967 1973 1956 1976 4500 1987 1991 1983
#  1960 1969 1950 1978 1980 1984 1963 1977 1961 1968 1934 1965 1971 1966
#  1979 1981 1970 1974 1910 1975 5000 4100 2019 1959 9996 9999 6200 1964
#  1958 1800 1948 1931 1943 9000 1941 1962 1927 1937 1929 1000 1957 1952
#  1111 1955 1939 8888 1954 1938 2800 5911 1500 1953 1951 4800 1001]
# 22316    1000
# 49283    1001
# 24511    1111
# 35238    1500
# 10556    1800
# 32585    1800
# 28693    1910
# 42181    1910
# 15898    1910
# 3679     1910
# 30781    1910
# 33295    1910
# 45157    1910
# 22659    1910
# 46213    1910
# 21416    1927
# 22101    1929
# 11246    1931
# 2573     1934
# 2221     1934
# 26607    1937
# 39725    1937
# 21421    1937
# 23804    1937
# 26103    1938
# 24855    1939
# 25792    1941
# 13963    1941
# 11585    1943
# 11047    1948
# ...

# %% [markdown]
# Date range registation year column is 1910 - 2019 (2019 inlcuded), drop data out of scope.
# PowerPS;

# %%
autos['power_ps'].value_counts()
reg_unique = autos['power_ps'].unique()
years_sorted = autos['power_ps'].sort_values()
print(reg_unique)
print(years_sorted)
# Out:
# [  158   286   102    71     0   150    90   101    75   203   205   124
#    131   320   184   120   306   116    54   110   204    60   218   140
#    193   122    86    43    95   435    84   224    58    65    80   121
#    174   179    57   136   108    99   170   143   113   177   163   385
#     63   200   151   106    85   109   145   127   250   105    50   126
#    160   183    81   125   141   239   560    55    88   344   232    98
#    135    45    73   129   103    64   436    53    68   211   245   128
#    241   115   231   325   235   197   133   111   260    82    83   185
#    173    92    61   190    74   100    44    76    70   147   225   107
#     69   517   230   315     1   370   360   354   155   258   326    33
#     94   192   330   156   313    52   130   180   117   275   114   256
#    299   207   104   118    87   394   220   272   175   280   420   333
#     77   165    66    89   148     5   400   188   171   247    59    26
# ...

# %% [markdown]
# - Scope; horsepower; of 10 PS and max. 700 Power PS.
# - Model; has missing entries.
# - Odometer; is string date to be truned into numerical data
# - Registration month; is datetime.datetime data.
# - Add created; has datetime.datetime data.
# - Nr.of pictures has no one value, can be dropped.
# - Last seen; is datetime.datetime data

# %%
autos['odometer'] = autos['odometer'].str.replace('km','').str.replace(',','')
autos['odometer'] = autos['odometer'].astype(int)

# %%
autos['price'] = autos['price'].str.replace('$','').str.replace(',','')
autos['price'] = autos['price'].astype(int)

# %%
print(autos['odometer'].head(2))
print(autos['price'].head(2))
# Out:
# 0    150000
# 1    150000
# Name: odometer, dtype: int64
# 0    5000
# 1    8500
# Name: price, dtype: int64

# %%
autos.rename({'odometer':'odometer_km'}, axis=1, inplace=True)
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type         price  \
# count                 50000        50000   50000      50000  5.000000e+04
# unique                48213        38754       2          2           NaN
# top     2016-03-25 19:57:10  Ford_Fiesta  privat    Angebot           NaN
# freq                      3           78   49999      49999           NaN
# mean                    NaN          NaN     NaN        NaN  9.840044e+03
# std                     NaN          NaN     NaN        NaN  4.811044e+05
# min                     NaN          NaN     NaN        NaN  0.000000e+00
# 25%                     NaN          NaN     NaN        NaN  1.100000e+03
# 50%                     NaN          NaN     NaN        NaN  2.950000e+03
# 75%                     NaN          NaN     NaN        NaN  7.200000e+03
# max                     NaN          NaN     NaN        NaN  1.000000e+08
#
#        abtest vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %% [markdown]
# # Step 4
#
# Exploring the columns odometer_km & price indepth.

# %%
print(autos["odometer_km"].value_counts())
print(autos['odometer_km'].unique().shape)
print(autos["odometer_km"].sort_index(ascending= True))
print(autos['odometer_km'].describe())
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64
# (13,)
# 0        150000
# 1        150000
# 2         70000
# 3         70000
# 4        150000
# 5        150000
# 6        150000
# 7        150000
# 8        150000
# 9        150000
# 10       150000
# 11       150000
# 12        50000
# 13       150000
# 14       150000
# 15        80000
# 16       150000
# 17       150000
# 18       150000
# 19       150000
# 20       150000
# 21       150000
# 22        10000
# 23       150000
# 24        30000
# 25       150000
# 26       125000
# 27       150000
# 28       150000
# 29       150000
#           ...
# 49970     60000
# 49971    150000
# 49972    150000
# 49973    150000
# 49974    150000
# 49975    100000
# 49976    150000
# 49977    150000
# 49978    150000
# ...

# %%
print(autos["price"].value_counts())
print(autos["price"].unique().shape)
print(autos["price"].sort_index(ascending= True))
print(autos['price'].describe())
# Out:
# 0         1421
# 500        781
# 1500       734
# 2500       643
# 1000       639
# 1200       639
# 600        531
# 800        498
# 3500       498
# 2000       460
# 999        434
# 750        433
# 900        420
# 650        419
# 850        410
# 700        395
# 4500       394
# 300        384
# 2200       382
# 950        379
# 1100       376
# 1300       371
# 3000       365
# 550        356
# 1800       355
# 5500       340
# 1250       335
# 350        335
# 1600       327
# 1999       322
#           ...
# 46200        1
# 29600        1
# 13480        1
# 21700        1
# 7373         1
# 3279         1
# 4286         1
# 188          1
# 17830        1
# 9130         1
# 910          1
# 238          1
# 2671         1
# 69900        1
# 151990       1
# 2479         1
# 4510         1
# 86500        1
# 47499        1
# 16998        1
# 27299        1
# 41850        1
# 4780         1
# 686          1
# 6495         1
# 20790        1
# 8970         1
# ...

# %%
autos["price"].value_counts().sort_index(ascending=False).head(20)
autos = autos[autos["price"].between(1,351000)]
print(autos["price"].value_counts())
# Out:
# 500       781
# 1500      734
# 2500      643
# 1200      639
# 1000      639
# 600       531
# 3500      498
# 800       498
# 2000      460
# 999       434
# 750       433
# 900       420
# 650       419
# 850       410
# 700       395
# 4500      394
# 300       384
# 2200      382
# 950       379
# 1100      376
# 1300      371
# 3000      365
# 550       356
# 1800      355
# 5500      340
# 1250      335
# 350       335
# 1600      327
# 1999      322
# 400       321
#          ...
# 9773        1
# 20480       1
# 299000      1
# 22499       1
# 369         1
# 48300       1
# 46911       1
# 920         1
# 19666       1
# 24290       1
# 6578        1
# 1275        1
# 20987       1
# 61999       1
# 15199       1
# 5195        1
# 6770        1
# 1545        1
# 19968       1
# 3560        1
# 56800       1
# 44444       1
# 1385        1
# 4755        1
# 5689        1
# 14998       1
# 15470       1
# 9325        1
# 23650       1
# 566         1
# ...

# %% [markdown]
# # Data summary step 4
#
# Price column has 5.000 cars with a selling price of 0. This can be dropped.
# here are also a small number of listings with very high values, including 14 at around or over $1 million. Above we have excluded all prices of 0 and above 350K.

# %% [markdown]
# # Step 5
# There are 5 columns that should represent date values. Some of these columns were created by the crawler, some came from the website itself. date_crawled, last_seen, and ad_created columns are all identified as string values. We need to convert the data into a numerical values.

# %%
date_c = autos['date_crawled'].str[:10].value_counts(normalize=True, dropna=False)
last_s = autos['last_seen'].str[:10].value_counts(normalize=True, dropna=False).sort_index()
ad_c = autos['ad_created'].str[:10].value_counts(normalize=True, dropna=False).sort_index()

date_c.sort_index()
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: date_crawled, dtype: float64

# %% [markdown]
# Date crawled has start date 5 march 16 and enddate 7 apr 16.

# %%
last_s.sort_index()
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %% [markdown]
# Last seen has start date 5th march 16 and ends at 7th april 2016 approx one month

# %%
ad_c.sort_index()
# Out:
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
# 2015-12-30    0.000021
# 2016-01-03    0.000021
# 2016-01-07    0.000021
# 2016-01-10    0.000041
# 2016-01-13    0.000021
# 2016-01-14    0.000021
# 2016-01-16    0.000021
# 2016-01-22    0.000021
# 2016-01-27    0.000062
# 2016-01-29    0.000021
# 2016-02-01    0.000021
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-07    0.000021
# 2016-02-08    0.000021
# 2016-02-09    0.000021
# 2016-02-11    0.000021
# 2016-02-12    0.000041
# 2016-02-14    0.000041
# 2016-02-16    0.000021
# 2016-02-17    0.000021
# 2016-02-18    0.000041
# 2016-02-19    0.000062
# 2016-02-20    0.000041
# 2016-02-21    0.000062
#                 ...
# 2016-03-09    0.033151
# 2016-03-10    0.031895
# 2016-03-11    0.032904
# 2016-03-12    0.036755
# 2016-03-13    0.017008
# 2016-03-14    0.035190
# 2016-03-15    0.034016
# 2016-03-16    0.030125
# 2016-03-17    0.031278
# ...

# %% [markdown]
# Ad created started 11th of june in 2015 and ends 7th of april 2016

# %%
print(autos['registration_year'].describe())
print('\n')
print(autos['registration_year'].unique())
print('\n')
print(autos['registration_year'].dtype)
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64
#
#
# [2004 1997 2009 2007 2003 2006 1995 1998 2000 2017 2010 1999 1982 1990
#  2015 2014 1996 1992 2002 2012 2011 2005 2008 1985 2016 1994 1986 2001
#  2018 2013 1972 1993 1988 1989 1973 1967 1976 4500 1987 1991 1983 1960
#  1969 1950 1978 1980 1984 1963 1977 1961 1968 1934 1965 1971 1966 1979
#  1981 1970 1974 1910 1975 5000 4100 2019 1956 9999 6200 1964 1959 1958
#  1800 1948 1931 1943 1941 1962 1927 1937 1929 1000 1957 1952 1111 1955
#  1939 8888 1954 1938 2800 5911 1953 1951 4800 1001 9000]
#
#
# int64

# %%
print(autos['registration_year'].value_counts().sort_index(ascending=False))
# Out:
# 9999       3
# 9000       1
# 8888       1
# 6200       1
# 5911       1
# 5000       4
# 4800       1
# 4500       1
# 4100       1
# 2800       1
# 2019       2
# 2018     470
# 2017    1392
# 2016    1220
# 2015     392
# 2014     663
# 2013     803
# 2012    1310
# 2011    1623
# 2010    1589
# 2009    2085
# 2008    2215
# 2007    2277
# 2006    2670
# 2005    2936
# 2004    2703
# 2003    2699
# 2002    2486
# 2001    2636
# 2000    3156
#         ...
# 1964      12
# 1963       8
# 1962       4
# 1961       6
# 1960      23
# 1959       6
# 1958       4
# 1957       2
# 1956       4
# 1955       2
# 1954       2
# 1953       1
# 1952       1
# 1951       2
# 1950       3
# 1948       1
# 1943       1
# 1941       2
# 1939       1
# 1938       1
# 1937       4
# 1934       2
# 1931       1
# 1929       1
# 1927       1
# 1910       5
# 1800       2
# 1111       1
# 1001       1
# 1000       1
# Name: registration_year, Length: 95, dtype: int64

# %% [markdown]
# # Summary Registration_year
#
# Most cars are registered between 2000 and 2020
# Date range is between 1900 and 2020

# %%
autos = autos[autos['registration_year'].between(1899,2017)]

# %%
print(autos['registration_year'].describe())
print('\n')
print(autos['registration_year'].unique())
print(autos['registration_year'].dtype)
# Out:
# count    48073.000000
# mean      2003.318724
# std          7.464077
# min       1910.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2017.000000
# Name: registration_year, dtype: float64
#
#
# [2004 1997 2009 2007 2003 2006 1995 1998 2000 2017 2010 1999 1982 1990
#  2015 2014 1996 1992 2002 2012 2011 2005 2008 1985 2016 1994 1986 2001
#  2013 1972 1993 1988 1989 1973 1967 1976 1987 1991 1983 1960 1969 1950
#  1978 1980 1984 1963 1977 1961 1968 1934 1965 1971 1966 1979 1981 1970
#  1974 1910 1975 1956 1964 1959 1958 1948 1931 1943 1941 1962 1927 1937
#  1929 1957 1952 1955 1939 1954 1938 1953 1951]
# int64

# %%
autos['registration_year'].value_counts(normalize=True)
# Out:
# 2000    0.065650
# 2005    0.061074
# 1999    0.060263
# 2004    0.056227
# 2003    0.056144
# 2006    0.055541
# 2001    0.054833
# 2002    0.051713
# 1998    0.049154
# 2007    0.047365
# 2008    0.046076
# 2009    0.043372
# 1997    0.040584
# 2011    0.033761
# 2010    0.033054
# 2017    0.028956
# 1996    0.028561
# 2012    0.027250
# 1995    0.025524
# 2016    0.025378
# 2013    0.016704
# 2014    0.013792
# 1994    0.013084
# 1993    0.008841
# 2015    0.008154
# 1992    0.007697
# 1990    0.007218
# 1991    0.007052
# 1989    0.003619
# 1988    0.002808
#           ...
# 1966    0.000458
# 1976    0.000437
# 1969    0.000395
# 1975    0.000374
# 1965    0.000354
# 1964    0.000250
# 1963    0.000166
# 1959    0.000125
# 1961    0.000125
# 1910    0.000104
# 1962    0.000083
# 1937    0.000083
# 1958    0.000083
# 1956    0.000083
# 1950    0.000062
# 1934    0.000042
# 1954    0.000042
# 1957    0.000042
# 1951    0.000042
# 1941    0.000042
# 1955    0.000042
# ...

# %%
autos['brand'].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'seat', 'renault', 'mercedes_benz', 'audi', 'sonstige_autos',
#        'opel', 'mazda', 'porsche', 'mini', 'toyota', 'dacia', 'nissan',
#        'jeep', 'saab', 'volvo', 'mitsubishi', 'jaguar', 'fiat', 'skoda',
#        'subaru', 'kia', 'citroen', 'chevrolet', 'hyundai', 'honda',
#        'daewoo', 'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'lada',
#        'rover', 'daihatsu', 'lancia'], dtype=object)

# %%
brand_counts = autos["brand"].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > .05].index
print(common_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
brand_mean_prices = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_price = brand_only["price"].mean()
    brand_mean_prices[brand] = int(mean_price)

brand_mean_prices
# Out:
# {'audi': 9239,
#  'bmw': 8284,
#  'ford': 3732,
#  'mercedes_benz': 8528,
#  'opel': 2952,
#  'volkswagen': 5351}
